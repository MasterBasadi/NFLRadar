# %% [markdown]
# # NFLRadar – Model Predictions Visualization
# ## Author: Basit Umair
# ## Description:
# This notebook loads the output of the prediction model (`out/nfl_predictions.csv`)
# and visualizes key trends such as predicted vs. actual performance,
# team-level trends, and model accuracy over time.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use("ggplot") ## make plots look clean
sns.set_theme(style="whitegrid")

# Load predictions
preds = pd.read_csv("out/nfl_predictions.csv")

preds.head()
